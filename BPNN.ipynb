# %%
import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD
import matplotlib.pyplot as plt

# Load the MNIST dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train = X_train.reshape(X_train.shape[0], -1) / 255.0
X_test = X_test.reshape(X_test.shape[0], -1) / 255.0
y_train = np.eye(10)[y_train]
y_test = np.eye(10)[y_test]

# Define the architecture of the BPNN
model = Sequential()
model.add(Dense(128, input_dim=784, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

# Compile the model with the loss function, optimizer, and metric
sgd = SGD(lr=0.01, momentum=0.9)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

# Train the model on the MNIST training set, and evaluate it on the test set
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=20, batch_size=32)

# Plot the training loss and accuracy
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.title('Training and Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='test')
plt.title('Training and Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step
# Epoch 1/20
# 1875/1875 [==============================] - 18s 8ms/step - loss: 0.2884 - accuracy: 0.9143 - val_loss: 0.1388 - val_accuracy: 0.9575
# Epoch 2/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1187 - accuracy: 0.9630 - val_loss: 0.1136 - val_accuracy: 0.9669
# Epoch 3/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0857 - accuracy: 0.9737 - val_loss: 0.0857 - val_accuracy: 0.9728
# Epoch 4/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0639 - accuracy: 0.9802 - val_loss: 0.0800 - val_accuracy: 0.9752
# Epoch 5/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0504 - accuracy: 0.9842 - val_loss: 0.0892 - val_accuracy: 0.9728
# Epoch 6/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0404 - accuracy: 0.9875 - val_loss: 0.0740 - val_accuracy: 0.9774
# Epoch 7/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0334 - accuracy: 0.9898 - val_loss: 0.0843 - val_accuracy: 0.9755
# Epoch 8/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0286 - accuracy: 0.9908 - val_loss: 0.0703 - val_accuracy: 0.9777
# Epoch 9/20
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.0220 - accuracy: 0.9931 - val_loss: 0.0691 - val_accuracy: 0.9783
# Epoch 10/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0181 - accuracy: 0.9944 - val_loss: 0.0822 - val_accuracy: 0.9759
# Epoch 11/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0139 - accuracy: 0.9959 - val_loss: 0.0856 - val_accuracy: 0.9745
# Epoch 12/20
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0118 - accuracy: 0.9966 - val_loss: 0.0816 - val_accuracy: 0.9780
# Epoch 13/20
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0094 - accuracy: 0.9977 - val_loss: 0.0784 - val_accuracy: 0.9780
# Epoch 14/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0070 - accuracy: 0.9984 - val_loss: 0.0765 - val_accuracy: 0.9780
# Epoch 15/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0042 - accuracy: 0.9991 - val_loss: 0.0807 - val_accuracy: 0.9774
# Epoch 16/20
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0029 - accuracy: 0.9995 - val_loss: 0.0860 - val_accuracy: 0.9782
# Epoch 17/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0016 - accuracy: 0.9999 - val_loss: 0.0802 - val_accuracy: 0.9790
# Epoch 18/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0825 - val_accuracy: 0.9788
# Epoch 19/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 9.5935e-04 - accuracy: 1.0000 - val_loss: 0.0804 - val_accuracy: 0.9795
# Epoch 20/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 7.6571e-04 - accuracy: 1.0000 - val_loss: 0.0820 - val_accuracy: 0.9802

# %% [markdown]
# This code loads the MNIST dataset using the mnist.load_data() function, and preprocesses the data by reshaping the images to 1D vectors and normalizing the pixel values to be between 0 and 1. The labels are one-hot encoded using np.eye(10).
#
# We define the architecture of the BPNN using the Keras Sequential API, with two hidden layers of 128 and 64 neurons, respectively, and ReLU activation functions. The output layer has 10 neurons and a softmax activation function. We then compile the model with the categorical cross-entropy loss function, the SGD optimizer with a learning rate of 0.01 and momentum of 0.9, and the accuracy metric.
#
# We train the model on the MNIST training set for 20 epochs with a batch size of 32, and evaluate it on the test set. We also record the training history in the history variable.
#
# Finally, we generate two plots using matplotlib to visualize the training process: one for the training and test loss, and one for the training and test accuracy.
